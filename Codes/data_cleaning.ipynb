# %%
import pandas as pd

sales_data = pd.read_csv("F:\GUVI\Project\Dominos - Predictive Purchase Order System\DATA\Pizza_Sale - pizza_sales.csv")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:4: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\syeda\AppData\Local\Temp\ipykernel_5840\3870494756.py:3: SyntaxWarning: invalid escape sequence '\G'
#   sales_data = pd.read_csv("F:\GUVI\Project\Dominos - Predictive Purchase Order System\DATA\Pizza_Sale - pizza_sales.csv")
# C:\Users\syeda\AppData\Local\Temp\ipykernel_5840\3870494756.py:4: SyntaxWarning: invalid escape sequence '\G'
#   ingredients_data = pd.read_csv("F:\GUVI\Project\Dominos - Predictive Purchase Order System\DATA\Pizza_ingredients - Pizza_ingredients.csv")

# %%
pd.set_option("display.max_columns", 20)

# %%
sales_data.head(10)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1         2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2         3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3         4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4         5         2     mexicana_m         1   1/1/2015   11:57:40
# 5         6         2     thai_ckn_l         1   1/1/2015   11:57:40
# 6         7         3    ital_supr_m         1   1/1/2015   12:12:28
# 7         8         3   prsc_argla_l         1   1/1/2015   12:12:28
# 8         9         4    ital_supr_m         1   1/1/2015   12:16:31
# 9        10         5    ital_supr_m         1   1/1/2015   12:21:30
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
sales_data.duplicated().sum()
# Out:
# 0

# %%
sales_data.isnull().mean() * 100
# Out:
# pizza_id             0.000000
# order_id             0.000000
# pizza_name_id        0.032908
# quantity             0.000000
# order_date           0.000000
# order_time           0.000000
# unit_price           0.000000
# total_price          0.014397
# pizza_size           0.000000
# pizza_category       0.047306
# pizza_ingredients    0.026738
# pizza_name           0.014397
# dtype: float64

# %%
sales_data['pizza_name_id'].isnull().value_counts()
# Out:
# pizza_name_id
# False    48604
# True        16
# Name: count, dtype: int64

# %%
["pizza_name_id", "pizza_category", "pizza_ingredients", "pizza_name"]
# Out:
# ['pizza_name_id', 'pizza_category', 'pizza_ingredients', 'pizza_name']

# %%
sales_data['pizza_name_id'].mode(0)
# Out:
# 0    big_meat_s
# Name: pizza_name_id, dtype: object

# %%
sales_data.loc[sales_data["pizza_name_id"].isnull()]
# Out:
#      pizza_id  order_id pizza_name_id  quantity order_date order_time  \
# 36         37        15           NaN         1   1/1/2015   13:33:00
# 37         38        15           NaN         1   1/1/2015   13:33:00
# 38         39        15           NaN         1   1/1/2015   13:33:00
# 39         40        16           NaN         1   1/1/2015   13:34:07
# 40         41        16           NaN         1   1/1/2015   13:34:07
# 41         42        16           NaN         1   1/1/2015   13:34:07
# 309       310       131           NaN         1   2/1/2015   21:33:10
# 310       311       131           NaN         1   2/1/2015   21:33:10
# 311       312       132           NaN         1   2/1/2015   21:42:45
# 312       313       133           NaN         1   2/1/2015   22:00:17
# 313       314       133           NaN         1   2/1/2015   22:00:17
# 415       416       175           NaN         1   3/1/2015   17:50:51
# ...

# %%
filtered_data = sales_data[sales_data["pizza_name"] == "The Greek Pizza"]

# %%
filtered_data
# Out:
#        pizza_id  order_id pizza_name_id  quantity  order_date order_time  \
# 11           12         6   the_greek_s         1    1/1/2015   12:29:36
# 34           35        14   the_greek_s         1    1/1/2015   13:14:19
# 38           39        15           NaN         1    1/1/2015   13:33:00
# 84           85        34   the_greek_s         1    1/1/2015   16:21:21
# 121         122        50  the_greek_xl         1    1/1/2015   18:41:01
# ...         ...       ...           ...       ...         ...        ...
# 48372     48373     21243  the_greek_xl         1  29-12-2015   21:15:19
# 48418     48419     21260   the_greek_m         1  30-12-2015   15:45:32
# 48436     48437     21270  the_greek_xl         1  30-12-2015   18:59:45
# 48529     48530     21308   the_greek_l         1  31-12-2015   16:44:35
# 48540     48541     21314  the_greek_xl         1  31-12-2015   17:36:51
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
# Step 1: rows where 'pizza_name_id' is null
null_rows = sales_data['pizza_name_id'].isnull()

# %%
sales_data.loc[null_rows, 'pizza_name_id']
# Out:
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 309    NaN
# 310    NaN
# 311    NaN
# 312    NaN
# 313    NaN
# 415    NaN
# 416    NaN
# 417    NaN
# 418    NaN
# 419    NaN
# Name: pizza_name_id, dtype: object

# %%
# Step 2: Only fill the NaN values, keeping other values intact
sales_data.loc[null_rows, 'pizza_name_id'] = sales_data.groupby(['pizza_name', 'pizza_category', 'pizza_size'])['pizza_name_id'].transform(lambda x: x.ffill().bfill())[null_rows]

# %%
# Check if the NaN values are filled correctly
print(sales_data['pizza_name_id'].isnull().sum())
# Out:
# 0

# %%
id = [36,37,38,39,40,41,309,310,311,312,313,415,416,417,418,419]

sales_data.loc[id]
# Out:
#      pizza_id  order_id   pizza_name_id  quantity order_date order_time  \
# 36         37        15   five_cheese_l         1   1/1/2015   13:33:00
# 37         38        15   soppressata_l         1   1/1/2015   13:33:00
# 38         39        15     the_greek_s         1   1/1/2015   13:33:00
# 39         40        16   four_cheese_l         1   1/1/2015   13:34:07
# 40         41        16    napolitana_s         1   1/1/2015   13:34:07
# 41         42        16      thai_ckn_l         1   1/1/2015   13:34:07
# 309       310       131  green_garden_s         1   2/1/2015   21:33:10
# 310       311       131  spinach_supr_s         1   2/1/2015   21:33:10
# 311       312       132     pepperoni_s         1   2/1/2015   21:42:45
# 312       313       133       bbq_ckn_l         1   2/1/2015   22:00:17
# 313       314       133      hawaiian_l         1   2/1/2015   22:00:17
# 415       416       175     ital_supr_l         1   3/1/2015   17:50:51
# ...

# %%
sales_data.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id         0
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
sales_data.loc[sales_data["total_price"].isnull()]
# Out:
#      pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 781       782       341      bbq_ckn_m         1   6/1/2015   15:35:47
# 782       783       341    pepperoni_s         1   6/1/2015   15:35:47
# 783       784       342     sicilian_l         1   6/1/2015   15:44:12
# 784       785       342   southw_ckn_l         1   6/1/2015   15:44:12
# 785       786       343  five_cheese_l         1   6/1/2015   15:45:37
# 786       787       343  four_cheese_m         1   6/1/2015   15:45:37
# 787       788       344  ital_cpcllo_m         1   6/1/2015   16:01:11
#
#      unit_price  total_price pizza_size pizza_category  \
# 781       16.75          NaN          M        Chicken
# 782        9.75          NaN          S        Classic
# 783       20.25          NaN          L        Supreme
# 784       20.75          NaN          L        Chicken
# 785       18.50          NaN          L         Veggie
# 786       14.75          NaN          M         Veggie
# ...

# %%
filtered_data = sales_data[sales_data["quantity"] == 4]

# %%
filtered_data
# Out:
#        pizza_id  order_id pizza_name_id  quantity  order_date order_time  \
# 11976     11977      5264    big_meat_s         4  30-03-2015   13:24:35
# 18875     18876      8286    big_meat_s         4  19-05-2015   12:42:46
# 35496     35497     15674    cali_ckn_l         4  19-09-2015   14:16:35
#
#        unit_price  total_price pizza_size pizza_category  \
# 11976       12.00         48.0          S        Classic
# 18875       12.00         48.0          S        Classic
# 35496       20.75         83.0          L        Chicken
#
#                                        pizza_ingredients  \
# 11976  Bacon, Pepperoni, Italian Sausage, Chorizo Sau...
# 18875  Bacon, Pepperoni, Italian Sausage, Chorizo Sau...
# 35496  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
#
#                          pizza_name
# 11976            The Big Meat Pizza
# 18875            The Big Meat Pizza
# 35496  The California Chicken Pizza

# %%
null_rows = sales_data["total_price"].isnull()

# %%
sales_data.loc[null_rows, 'total_price']
# Out:
# 781   NaN
# 782   NaN
# 783   NaN
# 784   NaN
# 785   NaN
# 786   NaN
# 787   NaN
# Name: total_price, dtype: float64

# %%
sales_data.loc[null_rows, 'total_price'] = sales_data.loc[null_rows, 'unit_price'] * sales_data.loc[null_rows, 'quantity']

# %%
sales_data["total_price"].isnull().mean()
# Out:
# 0.0

# %%
sales_data.isnull().mean() * 100
# Out:
# pizza_id             0.000000
# order_id             0.000000
# pizza_name_id        0.000000
# quantity             0.000000
# order_date           0.000000
# order_time           0.000000
# unit_price           0.000000
# total_price          0.000000
# pizza_size           0.000000
# pizza_category       0.047306
# pizza_ingredients    0.026738
# pizza_name           0.014397
# dtype: float64

# %%
sales_data.loc[sales_data["pizza_category"].isnull()]
# Out:
#      pizza_id  order_id   pizza_name_id  quantity order_date order_time  \
# 426       427       181      mexicana_l         1   3/1/2015   18:49:32
# 427       428       182    brie_carre_s         1   3/1/2015   18:50:10
# 428       429       182  peppr_salami_l         1   3/1/2015   18:50:10
# 429       430       183    napolitana_m         1   3/1/2015   18:54:55
# 430       431       183    spin_pesto_l         1   3/1/2015   18:54:55
# 431       432       183    spin_pesto_s         1   3/1/2015   18:54:55
# 432       433       184      hawaiian_l         1   3/1/2015   18:59:05
# 433       434       185      sicilian_m         1   3/1/2015   19:08:33
# 434       435       185    spin_pesto_s         1   3/1/2015   19:08:33
# 435       436       186      mexicana_l         1   3/1/2015   19:36:00
# 486       487       207    spicy_ital_l         1   4/1/2015   12:03:58
# 487       488       208       bbq_ckn_l         1   4/1/2015   12:12:05
# ...

# %%
# Reset index after grouping to create a DataFrame
grouped_df = sales_data.groupby(['pizza_name', 'pizza_size'])['pizza_category'].first().reset_index()

# Display the DataFrame
grouped_df
# Out:
#                            pizza_name pizza_size pizza_category
# 0          The Barbecue Chicken Pizza          L        Chicken
# 1          The Barbecue Chicken Pizza          M        Chicken
# 2          The Barbecue Chicken Pizza          S        Chicken
# 3                  The Big Meat Pizza          S        Classic
# 4                The Brie Carre Pizza          S        Supreme
# ..                                ...        ...            ...
# 86             The Thai Chicken Pizza          M        Chicken
# 87             The Thai Chicken Pizza          S        Chicken
# 88  The Vegetables + Vegetables Pizza          L         Veggie
# 89  The Vegetables + Vegetables Pizza          M         Veggie
# 90  The Vegetables + Vegetables Pizza          S         Veggie
#
# [91 rows x 3 columns]

# %%
null_rows = sales_data["pizza_category"].isnull()

# %%
sales_data.loc[null_rows, 'pizza_category']
# Out:
# 426    NaN
# 427    NaN
# 428    NaN
# 429    NaN
# 430    NaN
# 431    NaN
# 432    NaN
# 433    NaN
# 434    NaN
# 435    NaN
# 486    NaN
# 487    NaN
# 488    NaN
# 489    NaN
# 490    NaN
# 491    NaN
# 511    NaN
# 512    NaN
# 513    NaN
# 514    NaN
# 515    NaN
# 516    NaN
# 517    NaN
# Name: pizza_category, dtype: object

# %%
sales_data.loc[null_rows, "pizza_category"] = sales_data.groupby(['pizza_name', 'pizza_size'])['pizza_category'].transform(lambda x: x.ffill().bfill())[null_rows]

# %%
sales_data["pizza_category"].isnull().mean()
# Out:
# 0.0

# %%
sales_data.loc[sales_data["pizza_ingredients"].isnull()]
# Out:
#      pizza_id  order_id   pizza_name_id  quantity order_date order_time  \
# 580       581       254   five_cheese_l         1   4/1/2015   22:22:13
# 581       582       255   five_cheese_l         1   5/1/2015   11:23:35
# 582       583       255  green_garden_m         1   5/1/2015   11:23:35
# 583       584       255      hawaiian_l         1   5/1/2015   11:23:35
# 584       585       255   spinach_fet_m         1   5/1/2015   11:23:35
# 585       586       256   pep_msh_pep_l         1   5/1/2015   11:56:06
# 586       587       257      cali_ckn_l         1   5/1/2015   11:59:04
# 630       631       277   four_cheese_m         1   5/1/2015   15:41:50
# 631       632       278   ital_veggie_m         1   5/1/2015   15:49:21
# 632       633       278    southw_ckn_l         1   5/1/2015   15:49:21
# 633       634       279      cali_ckn_m         1   5/1/2015   16:07:03
# 634       635       279   ckn_alfredo_m         1   5/1/2015   16:07:03
# ...

# %%
null_rows = sales_data["pizza_ingredients"].isnull()

# %%
sales_data.loc[null_rows, "pizza_ingredients"]
# Out:
# 580    NaN
# 581    NaN
# 582    NaN
# 583    NaN
# 584    NaN
# 585    NaN
# 586    NaN
# 630    NaN
# 631    NaN
# 632    NaN
# 633    NaN
# 634    NaN
# 635    NaN
# Name: pizza_ingredients, dtype: object

# %%
sales_data.loc[null_rows, "pizza_ingredients"] = sales_data.groupby(['pizza_name', 'pizza_category', 'pizza_size'])['pizza_ingredients'].transform(lambda x: x.ffill().bfill())[null_rows]

# %%
sales_data["pizza_ingredients"].isnull().mean()
# Out:
# 0.0

# %%
sales_data.loc[[586]]
# Out:
#      pizza_id  order_id pizza_name_id  quantity order_date order_time  \
# 586       587       257    cali_ckn_l         1   5/1/2015   11:59:04
#
#      unit_price  total_price pizza_size pizza_category  \
# 586       20.75        20.75          L        Chicken
#
#                                      pizza_ingredients  \
# 586  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
#
#                        pizza_name
# 586  The California Chicken Pizza

# %%
sales_data.isnull().mean()
# Out:
# pizza_id             0.000000
# order_id             0.000000
# pizza_name_id        0.000000
# quantity             0.000000
# order_date           0.000000
# order_time           0.000000
# unit_price           0.000000
# total_price          0.000000
# pizza_size           0.000000
# pizza_category       0.000000
# pizza_ingredients    0.000000
# pizza_name           0.000144
# dtype: float64

# %%
sales_data["pizza_name"].isnull().sum()
# Out:
# 7

# %%
sales_data.loc[sales_data["pizza_name"].isnull()]
# Out:
#      pizza_id  order_id pizza_name_id  quantity order_date order_time  \
# 688       689       303   pepperoni_s         1   5/1/2015   20:02:51
# 689       690       304    hawaiian_s         1   5/1/2015   20:07:58
# 690       691       304    mexicana_l         1   5/1/2015   20:07:58
# 691       692       305   pepperoni_l         1   5/1/2015   20:35:40
# 692       693       305    sicilian_s         1   5/1/2015   20:35:40
# 693       694       305  spicy_ital_m         1   5/1/2015   20:35:40
# 694       695       306    big_meat_s         1   5/1/2015   20:37:40
#
#      unit_price  total_price pizza_size pizza_category  \
# 688        9.75         9.75          S        Classic
# 689       10.50        10.50          S        Classic
# 690       20.25        20.25          L         Veggie
# 691       15.25        15.25          L        Classic
# 692       12.25        12.25          S        Supreme
# 693       16.50        16.50          M        Supreme
# ...

# %%
null_rows = sales_data["pizza_name"].isnull()

sales_data.loc[null_rows, "pizza_name"]
# Out:
# 688    NaN
# 689    NaN
# 690    NaN
# 691    NaN
# 692    NaN
# 693    NaN
# 694    NaN
# Name: pizza_name, dtype: object

# %%
sales_data.loc[null_rows, "pizza_name"] = sales_data.groupby(["pizza_category", "pizza_name_id"])["pizza_name"].transform(lambda x : x.ffill().bfill())[null_rows]

# %%
sales_data["pizza_name"].isnull().mean()
# Out:
# 0.0

# %%
sales_data.isnull().mean()* 100
# Out:
# pizza_id             0.0
# order_id             0.0
# pizza_name_id        0.0
# quantity             0.0
# order_date           0.0
# order_time           0.0
# unit_price           0.0
# total_price          0.0
# pizza_size           0.0
# pizza_category       0.0
# pizza_ingredients    0.0
# pizza_name           0.0
# dtype: float64

# %%
sales_data.duplicated().sum()
# Out:
# 0

# %%
# Saving the cleaned data
sales_data.to_csv("Pizza_sales.csv")

# %%
ingredients_data = pd.read_csv("F:\GUVI\Project\Dominos - Predictive Purchase Order System\DATA\Pizza_ingredients - Pizza_ingredients.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\syeda\AppData\Local\Temp\ipykernel_5840\1972769397.py:1: SyntaxWarning: invalid escape sequence '\G'
#   ingredients_data = pd.read_csv("F:\GUVI\Project\Dominos - Predictive Purchase Order System\DATA\Pizza_ingredients - Pizza_ingredients.csv")

# %%
ingredients_data.head(20)
# Out:
#    pizza_name_id                  pizza_name  pizza_ingredients  \
# 0      bbq_ckn_l  The Barbecue Chicken Pizza  Barbecued Chicken
# 1      bbq_ckn_l  The Barbecue Chicken Pizza        Red Peppers
# 2      bbq_ckn_l  The Barbecue Chicken Pizza      Green Peppers
# 3      bbq_ckn_l  The Barbecue Chicken Pizza           Tomatoes
# 4      bbq_ckn_l  The Barbecue Chicken Pizza         Red Onions
# 5      bbq_ckn_l  The Barbecue Chicken Pizza     Barbecue Sauce
# 6      bbq_ckn_m  The Barbecue Chicken Pizza  Barbecued Chicken
# 7      bbq_ckn_m  The Barbecue Chicken Pizza        Red Peppers
# 8      bbq_ckn_m  The Barbecue Chicken Pizza      Green Peppers
# 9      bbq_ckn_m  The Barbecue Chicken Pizza           Tomatoes
# 10     bbq_ckn_m  The Barbecue Chicken Pizza         Red Onions
# 11     bbq_ckn_m  The Barbecue Chicken Pizza     Barbecue Sauce
# 12     bbq_ckn_s  The Barbecue Chicken Pizza  Barbecued Chicken
# 13     bbq_ckn_s  The Barbecue Chicken Pizza        Red Peppers
# ...

# %%
ingredients_data.duplicated().sum()
# Out:
# 0

# %%
ingredients_data.isnull().mean()
# Out:
# pizza_name_id         0.000000
# pizza_name            0.000000
# pizza_ingredients     0.000000
# Items_Qty_In_Grams    0.007722
# dtype: float64

# %%
null_rows = ingredients_data["Items_Qty_In_Grams"].isnull()
ingredients_data.loc[null_rows, "Items_Qty_In_Grams"]
# Out:
# 24    NaN
# 149   NaN
# 152   NaN
# 155   NaN
# Name: Items_Qty_In_Grams, dtype: float64

# %%
ingredients_data.loc[ingredients_data["Items_Qty_In_Grams"].isnull()]
# Out:
#     pizza_name_id            pizza_name   pizza_ingredients  \
# 24   brie_carre_s  The Brie Carre Pizza  Caramelized Onions
# 149    hawaiian_l    The Hawaiian Pizza          Sliced Ham
# 152    hawaiian_m    The Hawaiian Pizza          Sliced Ham
# 155    hawaiian_s    The Hawaiian Pizza          Sliced Ham
#
#      Items_Qty_In_Grams
# 24                  NaN
# 149                 NaN
# 152                 NaN
# 155                 NaN

# %%
ingredients_data[ingredients_data["pizza_name"] == "The Brie Carre Pizza"]
# Out:
#    pizza_name_id            pizza_name   pizza_ingredients  Items_Qty_In_Grams
# 22  brie_carre_s  The Brie Carre Pizza   Brie Carre Cheese                30.0
# 23  brie_carre_s  The Brie Carre Pizza          Prosciutto                30.0
# 24  brie_carre_s  The Brie Carre Pizza  Caramelized Onions                 NaN
# 25  brie_carre_s  The Brie Carre Pizza               Pears                10.0
# 26  brie_carre_s  The Brie Carre Pizza               Thyme                 5.0
# 27  brie_carre_s  The Brie Carre Pizza              Garlic                 5.0

# %%
ingredients_data["Items_Qty_In_Grams"].fillna(0, inplace=True)
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_5840\2132361267.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ingredients_data["Items_Qty_In_Grams"].fillna(0, inplace=True)

# %%
ingredients_data.isnull().mean()
# Out:
# pizza_name_id         0.0
# pizza_name            0.0
# pizza_ingredients     0.0
# Items_Qty_In_Grams    0.0
# dtype: float64

# %%
# saving the data

ingredients_data.to_csv("ingredients_data.csv")
